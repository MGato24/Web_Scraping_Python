# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/GATO/Desktop/Prueba_Scrapy/Prueba_1/quotes.csv")
data
# Out:
#                                                   text              author  \
# 0    “The world as we have created it is a process ...     Albert Einstein
# 1    “It is our choices, Harry, that show what we t...        J.K. Rowling
# 2    “There are only two ways to live your life. On...     Albert Einstein
# 3    “The person, be it gentleman or lady, who has ...         Jane Austen
# 4    “Imperfection is beauty, madness is genius and...      Marilyn Monroe
# ..                                                 ...                 ...
# 105  “You never really understand a person until yo...          Harper Lee
# 106  “You have to write the book that wants to be w...   Madeleine L'Engle
# 107  “Never tell the truth to people who are not wo...          Mark Twain
# 108        “A person's a person, no matter how small.”           Dr. Seuss
# 109  “... a mind needs books as a sword needs a whe...  George R.R. Martin
#
#                                                   tags
# ...
